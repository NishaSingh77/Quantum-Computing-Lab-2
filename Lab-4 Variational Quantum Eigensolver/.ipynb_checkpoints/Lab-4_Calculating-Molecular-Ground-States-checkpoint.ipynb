# %% [markdown]
# # Ground State of a Molecule
# In this lab, we will calculate the ground state of a simple molecule and find the optimized interatomic distance between atoms.  We will also examine the performance of several different variational optimizers and find the ground state of a given, non-chemical Hamiltonian.

# %% [markdown]
# # Preparing  and Transforming the Molecular Hamiltonian Operator
#
# To get us started with finding the ground state of a molecule, we should *first* examine how we wish to characterize the Hamiltonian of our molecule.  The main problem with accurately simulating molecules is that the true Hamiltonian is an $N$-body problem which is quite difficult to deal with.  Instead, the common canonical approach is simplify the system into $N$ one-body problems where each electron responds to the mean-field of all the others.  This approach is known as the Hartree-Fock method and has a Hamiltonian written in the form:
#
# $$
#     H = \sum_{ij} h_{ij}\hat{c}_i^\dagger\hat{c}_j + \frac{1}{2}\sum_{ijkl} h_{ijkl} \hat{c}_i^\dagger\hat{c}_j^\dagger\hat{c}_k\hat{c}_l
# $$
#
# where the creation ($\hat{c}_i^\dagger$) and annihilation ($\hat{c}_i$) operators act on a basis of molecular orbitals electrons are able to occupy ($\phi_i$).  Each of these orbitals can be occupied or unoccupied with a single electron of a given spin.  The parameters $h_{ij}$ and $h_{ijkl}$ store the one-body and two body integrals of the molecular orbital basis functions
#
# $$
#     h_{ij} = \int \phi_i^*(r)\left(-\frac{1}{2}\nabla^2 - \sum_I \frac{Z_I}{R_I-r} \right)\phi_i(r) dr \\ \\
#     h_{ijkl} = \int \frac{\phi_i^*(r_1)\phi_j^*(r_2)\phi_k(r_1)\phi_l(r_2)}{|r_1-r_2|}dr_1dr_2
# $$
# where the values $Z_I$ and $R_I$ are the charge and position of each of the atomic nuclei in the molecule.
#
# Luckily, computational chemists have developed libraries which can calculate these integrals for us so we don't have to!  Qiskit accesses these libraries through what are called *drivers*.  In the code below we will initialize an $H_2$ molecule at the ideal interatomic distance.

# %%
from qiskit_nature.drivers import UnitsType, Molecule
from qiskit_nature.drivers.second_quantization import (
    ElectronicStructureDriverType,
    ElectronicStructureMoleculeDriver,
)
from qiskit_nature.problems.second_quantization import ElectronicStructureProblem
import qiskit_nature as qk_nature
qk_nature.settings.dict_aux_operators = True


#Initalize the driver for the H2 molecule.  The input for this are the element symbol as string followed by
# an array of x, y, z positions in units of angstroms.
molecule = Molecule(
    geometry=[["H", [0.0, 0.0, 0.0]], ["H", [0.0, 0.0, 0.735]]])


driver = ElectronicStructureMoleculeDriver(
    molecule, basis="sto3g", driver_type=ElectronicStructureDriverType.PYQUANTE)


#This prepares the second quantized fermionic operator after computing the one and two body orbitals
es_problem = ElectronicStructureProblem(driver)
second_q_op = es_problem.second_q_ops()

print("Items of the second_q_op dict: \n")
for key, val in second_q_op.items():
    print(key,':', val, '\n')
# Out:
# Items of the second_q_op dict:
#
# ElectronicEnergy : Fermionic Operator
# register length=4, number terms=14
#   (0.18093120148374142+0j) * ( +_0 -_1 +_2 -_3 )
# + (-0.18093120148374134+0j) * ( +_0 -_1 -_2 +_3 )
# + (-0.18093120148374134+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.18093120148374128+0j) * ( -_0 +_1 -_2 +_3  ...
#
# ParticleNumber : Fermionic Operator
# register length=4, number terms=4
#   (1+0j) * ( +_0 -_0 )
# + (1+0j) * ( +_1 -_1 )
# + (1+0j) * ( +_2 -_2 )
# + (1+0j) * ( +_3 -_3 )
#
# AngularMomentum : Fermionic Operator
# register length=4, number terms=12
#   (1+0j) * ( +_0 -_1 -_2 +_3 )
# + (1+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.75+0j) * ( +_3 -_3 )
# + (0.75+0j) * ( +_2 -_2 )
# + (0.5+0j) * ( +_2 -_2 +_3 -_3 )
# + (0.75+0j) * ( +_1 -_1 )
# + (-1.5+0j) * ( +_1 -_1 ...
#
# Magnetization : Fermionic Operator
# register length=4, number terms=4
#   (0.5+0j) * ( +_0 -_0 )
# + (0.5+0j) * ( +_1 -_1 )
# + (-0.5+0j) * ( +_2 -_2 )
# + (-0.5+0j) * ( +_3 -_3 )

# %% [markdown]
# ## Transform Fermionic Operators to Pauli Operators
#
# Great!  Now we have computed the second quantized hamiltonian of $H_2$ written in the molecular orbital basis (the `ElectronicEnergy` operator is what we're after).  However, this is written in terms of fermionic operators which cannot be encoded onto the operators of a quantum computer.  In order to encode this Hamiltonian to a quantum computing environment, the operators need to be mapped to spin (Pauli) operators.
# ![image1](./images/jw_mapping.png)
# There exist many different mappings between fermionic and spin operators, each with their own properties, but the canonical (read: most popular as far as I know) transformation (and one that Qiskit already has support for) is the Jordan-Wigner transformation.  This transformation will map each molecular orbital to an individual qubit, thereby mapping the occupied and unnoccupied orbital state to the $|0\rangle$ and $|1\rangle$ state respectively.  The code below will take our second quantized Hamiltonian and write it in terms of Pauli operators.

# %%
from qiskit_nature.converters.second_quantization import QubitConverter
from qiskit_nature.mappers.second_quantization import JordanWignerMapper


qubit_converter = QubitConverter(mapper=JordanWignerMapper(), two_qubit_reduction=True)
H2_op = qubit_converter.convert(second_q_op['ElectronicEnergy'])
print(H2_op)
# Out:
# -0.8105479965981814 * IIII
# - 0.22575350027942775 * ZIII
# + 0.17218394351950977 * IZII
# + 0.12091263344524698 * ZZII
# - 0.22575350027942775 * IIZI
# + 0.17464343496146983 * ZIZI
# + 0.16614543381618233 * IZZI
# + 0.1721839435195099 * IIIZ
# + 0.16614543381618233 * ZIIZ
# + 0.1689275406336891 * IZIZ
# + 0.12091263344524698 * IIZZ
# + 0.045232800370935335 * XXXX
# + 0.045232800370935335 * YYXX
# + 0.045232800370935335 * XXYY
# + 0.045232800370935335 * YYYY

# %% [markdown]
# In this particular basis (STO-3G), 4 qubits are required to capture all the orbitals.  However, this can be reduced by taking advantage of parity operations using the `ParityMapper()` instead of the `JordanWignerMapper()` which reduces the number of qubits required to two.

# %%
from qiskit_nature.mappers.second_quantization import ParityMapper


qubit_converter = QubitConverter(mapper=ParityMapper(), two_qubit_reduction=True)
H2_op = qubit_converter.convert(second_q_op['ElectronicEnergy'], num_particles=es_problem.num_particles)
print(H2_op)
# Out:
# (-1.052373263488675-2.7755575615628914e-17j) * II
# - 0.39793744379893736 * ZI
# + (0.3979374437989376-2.7755575615628914e-17j) * IZ
# + (-0.011280107962794272+2.7755575615628914e-17j) * ZZ
# + (0.18093120148374128-3.469446951953614e-18j) * XX

# %% [markdown]
# Now the Hamiltonian for the $H_2$ molecule is ready!  The next step is to send this operator to the VQE

# %% [markdown]
# ## Running VQE

# %% [markdown]
# Recall in the previous notebook that the VQE algorithm consists of two pieces, the **variational form** (the structure of the variational circuit) and the **optimization algorithm** (which control how the parameters evolve).  Now that we have the operator we want to run, we are going to specify both of these and run them using the Aer simulator.  For this case we'll use the `SPSA` optimizer and the `EfficientSU2` ansatz with linear entanglement.

# %%
from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit import Aer
from qiskit.algorithms.optimizers import SPSA
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.circuit.library import EfficientSU2


#Creating a QuantumInstance object will create an environment with the same starting seeds,
# ensuring that the resulting measurement data from the Aer simulator is the same everytime.  You do
# not have to do this for the lab, you can just set quantum_instance=backend.

seed = 170
iterations = 125
algorithm_globals.random_seed = seed
backend = Aer.get_backend('aer_simulator')
qi = QuantumInstance(backend=backend, seed_simulator=seed, seed_transpiler=seed)



counts = []
values = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts.append(eval_count)
    values.append(mean)


    # we will probabaly play with the ansatz
ansatz = EfficientSU2(num_qubits=4, entanglement='linear')
spsa = SPSA(maxiter=iterations)
vqe = VQE(ansatz, optimizer=spsa, callback=store_intermediate_result, quantum_instance=qi)



result = vqe.compute_minimum_eigenvalue(operator=H2_op)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(counts, values)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# Text(0.5, 1.0, 'Convergence with no noise')

# %% [markdown]
# We'll also calculate the exact ground state energy for our `H2_op` variable and compare to what the VQE algorithm returned

# %%
npme = NumPyMinimumEigensolver()
result_npme = npme.compute_minimum_eigenvalue(operator=H2_op)
ref_value = result_npme.eigenvalue.real
print(f'VQE on Aer qasm simulator (no noise): {result.eigenvalue.real:.5f}')
print(f'Delta from reference energy value is {(result.eigenvalue.real - ref_value):.5f}')
# Out:
# VQE on Aer qasm simulator (no noise): -1.85379
# Delta from reference energy value is 0.00348

# %% [markdown]
# # &#128211; Compare the Performance of Variational Forms and Optimization Algorithms
#
# ## &#128211; Run the COBYLA, SLSQP, L_BFGS_B for the Linear and Fully entangled ansatz circuit to find the ground state of H2
#
# ### &#128211; Plot the energy against each step of the optimization.  Put all of this data in one or two plots to make the comparison easier to see.
#
# Feel free to read more about these optimizers [L_BFGS_B](https://qiskit.org/documentation/stubs/qiskit.algorithms.optimizers.L_BFGS_B.html?highlight=bfgs#qiskit.algorithms.optimizers.L_BFGS_B), [SLSQP](https://qiskit.org/documentation/stubs/qiskit.algorithms.optimizers.SLSQP.html?highlight=slsqp#qiskit.algorithms.optimizers.SLSQP), [COBYLA](https://qiskit.org/documentation/stubs/qiskit.algorithms.optimizers.COBYLA.html?highlight=cobyla#qiskit.algorithms.optimizers.COBYLA)

# %%
# OPIMIZER = L_BFGS_B

from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit import Aer
from qiskit.algorithms.optimizers import L_BFGS_B
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.circuit.library import EfficientSU2, TwoLocal


#Creating a QuantumInstance object will create an environment with the same starting seeds,
# ensuring that the resulting measurement data from the Aer simulator is the same everytime.  You do
# not have to do this for the lab, you can just set quantum_instance=backend.

seed = 170
iterations = 125
algorithm_globals.random_seed = seed
backend = Aer.get_backend('statevector_simulator')
qi = QuantumInstance(backend=backend, seed_simulator=seed, seed_transpiler=seed)



counts1 = []
values1 = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts1.append(eval_count)
    values1.append(mean)


# we will probabaly play with the ansatz
#ansatz = EfficientSU2(num_qubits=4, entanglement='linear')
ansatz = TwoLocal(rotation_blocks='ry', entanglement_blocks='cz')
bfgs = L_BFGS_B(maxiter=iterations)
vqe = VQE(ansatz, optimizer=bfgs, callback=store_intermediate_result, quantum_instance=qi)



result = vqe.compute_minimum_eigenvalue(operator=H2_op)

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(counts1, values1)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# Text(0.5, 1.0, 'Convergence with no noise')

# %%
# OPIMIZER = SLSQP

from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit import Aer
from qiskit.algorithms.optimizers import SLSQP
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.circuit.library import EfficientSU2, TwoLocal


#Creating a QuantumInstance object will create an environment with the same starting seeds,
# ensuring that the resulting measurement data from the Aer simulator is the same everytime.  You do
# not have to do this for the lab, you can just set quantum_instance=backend.

seed = 170
iterations = 125
algorithm_globals.random_seed = seed
backend = Aer.get_backend('statevector_simulator')
qi = QuantumInstance(backend=backend, seed_simulator=seed, seed_transpiler=seed)



counts2 = []
values2 = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts2.append(eval_count)
    values2.append(mean)


    # we will probabaly play with the ansatz
#ansatz = TwoLocal(rotation_blocks='ry', entanglement_blocks='cz')
ansatz = EfficientSU2(num_qubits=4, entanglement='linear')
slsqp = SLSQP(maxiter=iterations)
vqe = VQE(ansatz, optimizer=slsqp, callback=store_intermediate_result, quantum_instance=qi)



result = vqe.compute_minimum_eigenvalue(operator=H2_op)

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(counts2, values2)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# Text(0.5, 1.0, 'Convergence with no noise')

# %%
# OPIMIZER = COBYLA

from qiskit.utils import QuantumInstance, algorithm_globals
from qiskit import Aer
from qiskit.algorithms.optimizers import COBYLA
from qiskit.algorithms import VQE, NumPyMinimumEigensolver
from qiskit.circuit.library import EfficientSU2


#Creating a QuantumInstance object will create an environment with the same starting seeds,
# ensuring that the resulting measurement data from the Aer simulator is the same everytime.  You do
# not have to do this for the lab, you can just set quantum_instance=backend.

seed = 170
iterations = 125
algorithm_globals.random_seed = seed
backend = Aer.get_backend('aer_simulator')
qi = QuantumInstance(backend=backend, seed_simulator=seed, seed_transpiler=seed)



counts3 = []
values3 = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts3.append(eval_count)
    values3.append(mean)


    # we will probabaly play with the ansatz
ansatz = EfficientSU2(num_qubits=4, entanglement='linear')
cobyla = COBYLA(maxiter=iterations)
vqe = VQE(ansatz, optimizer=cobyla, callback=store_intermediate_result, quantum_instance=qi)



result = vqe.compute_minimum_eigenvalue(operator=H2_op)

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(counts3, values3)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# Text(0.5, 1.0, 'Convergence with no noise')

# %%
#You'll need to import the COBYLA, SLSQP, and L_BFGS_B optimizers the same way for SPSA above.  When 
#  initialized as a variable, you can set (among other things) the max number of iterations.  The default is 1000
#  and you may want to use a smaller amount when testing out your code.
#
#
# Your code goes here
#
#//// Here we will have to run the above code with ansatz thing with different optimizers. added by Nisha

# %%
#Modify the data you've gathered above using the reference value calculated with the NumpyMinimumEigenSolver()
#
# OPIMIZER = COBYLA


import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(counts1, values1)
ax.plot(counts2, values2)
ax.plot(counts3, values3)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
#
#print(values1)
#print("...........")
#print(values2)
# Out:
# Text(0.5, 1.0, 'Convergence with no noise')

# %% [markdown]
# ### &#128211; Plot the difference in energy from the reference value against each step of the optimization.  Put all this data into one or two plots

# %%
energy_diff1 = []
energy_diff2 = []
energy_diff3 = []

#print(values)
#print(values1)
#print(len(values))
#print(len(values1))
#print(counts1)
ref_value = result_npme.eigenvalue.real
print(ref_value)

for i in range(len(counts1)):
    energy = values1[i] - ref_value 
    energy_diff1.append(energy)

for i in range(len(counts2)):
    energy = values2[i] - ref_value 
    energy_diff2.append(energy)

for i in range(len(counts3)):
    energy = values3[i] - ref_value 
    energy_diff3.append(energy)

fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot( energy_diff1)
ax.plot( energy_diff2)
ax.plot( energy_diff3)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy Difference', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# -1.8572750815566381
# Text(0.5, 1.0, 'Convergence with no noise')

# %% [markdown]
# # &#128211; Plot the ground state energy of H2 as a function of interatomic distance

# %%
#Use functions!  You'll have to create a new H2 operator for each distance and send it through the VQE to 
# get the ground state energy.
#
#
# Your code goes here
#
#

import numpy as np
from qiskit_nature.drivers import UnitsType, Molecule
from qiskit_nature.drivers.second_quantization import (
    ElectronicStructureDriverType,
    ElectronicStructureMoleculeDriver,
)
from qiskit_nature.problems.second_quantization import ElectronicStructureProblem
import qiskit_nature as qk_nature
qk_nature.settings.dict_aux_operators = True


#Initalize the driver for the H2 molecule.  The input for this are the element symbol as string followed by
# an array of x, y, z positions in units of angstroms.
#molecule = Molecule(
#    geometry=[["H", [0.0, 0.0, 0.0]], ["H", [0.0, 0.0, 0.25]]])

for i in np.linspace(0.2,1,12):
    molecule = Molecule(
    geometry=[["H", [0.0, 0.0, 0.0]], ["H", [0.0, 0.0, i]]])
    #print(molecule)
    
    driver = ElectronicStructureMoleculeDriver(
    molecule, basis="sto3g", driver_type=ElectronicStructureDriverType.PYQUANTE)
    
#This prepares the second quantized fermionic operator after computing the one and two body orbitals
    es_problem = ElectronicStructureProblem(driver)
    second_q_op = es_problem.second_q_ops()

    #print("Items of the second_q_op dict: \n")
    for key, val in second_q_op.items():
        print(key,':', val, '\n') 
    
    qubit_converter = QubitConverter(mapper=JordanWignerMapper(), two_qubit_reduction=True)
    H2_op = qubit_converter.convert(second_q_op['ElectronicEnergy'])
    print(H2_op)
    #print('................................')
    qubit_converter = QubitConverter(mapper=ParityMapper(), two_qubit_reduction=True)
    H2_op = qubit_converter.convert(second_q_op['ElectronicEnergy'], num_particles=es_problem.num_particles)
    print(H2_op)

    seed = 170
    iterations = 125
    algorithm_globals.random_seed = seed
    backend = Aer.get_backend('aer_simulator')
    qi = QuantumInstance(backend=backend, seed_simulator=seed, seed_transpiler=seed)



    countsi = []
    valuesi = []
    def store_intermediate_result(eval_count, parameters, mean, std):
        countsi.append(eval_count)
        valuesi.append(mean)


    # we will probabaly play with the ansatz
    ansatz = EfficientSU2(num_qubits=4, entanglement='linear')
    spsa = SPSA(maxiter=iterations)
    vqe = VQE(ansatz, optimizer=spsa, callback=store_intermediate_result, quantum_instance=qi)


    atomic_dist = [0.00, 0.002, ]
    result = vqe.compute_minimum_eigenvalue(operator=H2_op)

distance = []
for i in np.linspace(0.2,1,12):
       distance.append(i)
    
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(distance, result)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# ElectronicEnergy : Fermionic Operator
# register length=4, number terms=14
#   (0.15797271403762103+0j) * ( +_0 -_1 +_2 -_3 )
# + (-0.1579727140376208+0j) * ( +_0 -_1 -_2 +_3 )
# + (-0.1579727140376208+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.1579727140376206+0j) * ( -_0 +_1 -_2 +_3 )
# + ...
#
# ParticleNumber : Fermionic Operator
# register length=4, number terms=4
#   (1+0j) * ( +_0 -_0 )
# + (1+0j) * ( +_1 -_1 )
# + (1+0j) * ( +_2 -_2 )
# + (1+0j) * ( +_3 -_3 )
#
# AngularMomentum : Fermionic Operator
# register length=4, number terms=12
#   (1+0j) * ( +_0 -_1 -_2 +_3 )
# + (1+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.75+0j) * ( +_3 -_3 )
# + (0.75+0j) * ( +_2 -_2 )
# + (0.5+0j) * ( +_2 -_2 +_3 -_3 )
# + (0.75+0j) * ( +_1 -_1 )
# + (-1.5+0j) * ( +_1 -_1 ...
#
# Magnetization : Fermionic Operator
# register length=4, number terms=4
#   (0.5+0j) * ( +_0 -_0 )
# + (0.5+0j) * ( +_1 -_1 )
# + (-0.5+0j) * ( +_2 -_2 )
# + (-0.5+0j) * ( +_3 -_3 )
#
# -0.33562928356404814 * IIII
# - 0.6482825261413945 * ZIII
# + 0.2822059730724342 * IZII
# + 0.14936430605884304 * ZZII
# - 0.6482825261413945 * IIZI
# + 0.20032331138413895 * ZIZI
# + 0.18885748456824825 * IZZI
# + 0.28220597307243434 * IIIZ
# + 0.18885748456824825 * ZIIZ
# + 0.19101549706364704 * IZIZ
# + 0.14936430605884304 * IIZZ
# + 0.0394931785094052 * XXXX
# + 0.0394931785094052 * YYXX
# + 0.0394931785094052 * XXYY
# + 0.0394931785094052 * YYYY
# (-0.6343578956817341+1.3877787807814457e-17j) * II
# + (-0.9304884992138284+2.7755575615628914e-17j) * ZI
# + (0.9304884992138287+5.551115123125783e-17j) * IZ
# + (-0.013623839311289479-1.3877787807814457e-17j) * ZZ
# + 0.15797271403762075 * XX
# ElectronicEnergy : Fermionic Operator
# register length=4, number terms=14
#   (0.15994945754727152+0j) * ( +_0 -_1 +_2 -_3 )
# + (-0.1599494575472713+0j) * ( +_0 -_1 -_2 +_3 )
# + (-0.1599494575472713+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.15994945754727108+0j) * ( -_0 +_1 -_2 +_3 )
#  ...
#
# ParticleNumber : Fermionic Operator
# register length=4, number terms=4
#   (1+0j) * ( +_0 -_0 )
# + (1+0j) * ( +_1 -_1 )
# + (1+0j) * ( +_2 -_2 )
# + (1+0j) * ( +_3 -_3 )
#
# AngularMomentum : Fermionic Operator
# register length=4, number terms=12
#   (1+0j) * ( +_0 -_1 -_2 +_3 )
# + (1+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.75+0j) * ( +_3 -_3 )
# + (0.75+0j) * ( +_2 -_2 )
# + (0.5+0j) * ( +_2 -_2 +_3 -_3 )
# + (0.75+0j) * ( +_1 -_1 )
# + (-1.5+0j) * ( +_1 -_1 ...
#
# Magnetization : Fermionic Operator
# register length=4, number terms=4
#   (0.5+0j) * ( +_0 -_0 )
# + (0.5+0j) * ( +_1 -_1 )
# + (-0.5+0j) * ( +_2 -_2 )
# + (-0.5+0j) * ( +_3 -_3 )
#
# -0.42826983742726044 * IIII
# - 0.5772864565239331 * ZIII
# + 0.26524519148064374 * IZII
# + 0.14650295533027818 * ZZII
# - 0.5772864565239331 * IIZI
# + 0.19745120950843287 * ZIZI
# + 0.186490319717096 * IZZI
# + 0.26524519148064396 * IIIZ
# + 0.186490319717096 * ZIIZ
# + 0.18891460791065784 * IZIZ
# + 0.14650295533027818 * IIZZ
# + 0.039987364386817825 * XXXX
# + 0.039987364386817825 * YYXX
# + 0.039987364386817825 * XXYY
# + 0.039987364386817825 * YYYY
# (-0.7212757480878165+1.3877787807814457e-17j) * II
# - 0.8425316480045764 * ZI
# + 0.8425316480045768 * IZ
# + (-0.013385177984898682+1.3877787807814457e-17j) * ZZ
# + 0.15994945754727127 * XX
# ElectronicEnergy : Fermionic Operator
# register length=4, number terms=14
#   (0.1624055904946854+0j) * ( +_0 -_1 +_2 -_3 )
# + (-0.16240559049468595+0j) * ( +_0 -_1 -_2 +_3 )
# + (-0.16240559049468595+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.16240559049468606+0j) * ( -_0 +_1 -_2 +_3 ) ...
#
# ParticleNumber : Fermionic Operator
# register length=4, number terms=4
#   (1+0j) * ( +_0 -_0 )
# + (1+0j) * ( +_1 -_1 )
# + (1+0j) * ( +_2 -_2 )
# + (1+0j) * ( +_3 -_3 )
#
# AngularMomentum : Fermionic Operator
# register length=4, number terms=12
#   (1+0j) * ( +_0 -_1 -_2 +_3 )
# + (1+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.75+0j) * ( +_3 -_3 )
# + (0.75+0j) * ( +_2 -_2 )
# + (0.5+0j) * ( +_2 -_2 +_3 -_3 )
# + (0.75+0j) * ( +_1 -_1 )
# + (-1.5+0j) * ( +_1 -_1 ...
#
# Magnetization : Fermionic Operator
# register length=4, number terms=4
#   (0.5+0j) * ( +_0 -_0 )
# + (0.5+0j) * ( +_1 -_1 )
# + (-0.5+0j) * ( +_2 -_2 )
# + (-0.5+0j) * ( +_3 -_3 )
#
# -0.5195480642693677 * IIII
# - 0.5050340702811034 * ZIII
# + 0.2478607308692672 * IZII
# + 0.14306141894902896 * ZZII
# - 0.5050340702811033 * IIZI
# + 0.1940830424585327 * ZIZI
# + 0.18366281657270045 * IZZI
# + 0.2478607308692674 * IIIZ
# + 0.18366281657270045 * ZIIZ
# + 0.18636322959104845 * IZIZ
# + 0.14306141894902896 * IIZZ
# + 0.04060139762367146 * XXXX
# + 0.04060139762367146 * YYXX
# + 0.04060139762367146 * XXYY
# + 0.04060139762367146 * YYYY
# -0.8056709021674253 * II
# - 0.7528948011503702 * ZI
# + (0.7528948011503704-5.551115123125783e-17j) * IZ
# + (-0.013120638904180235-1.3877787807814457e-17j) * ZZ
# + 0.16240559049468575 * XX
# ElectronicEnergy : Fermionic Operator
# register length=4, number terms=14
#   (0.16526346124299063+0j) * ( +_0 -_1 +_2 -_3 )
# + (-0.16526346124299096+0j) * ( +_0 -_1 -_2 +_3 )
# + (-0.16526346124299096+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.16526346124299085+0j) * ( -_0 +_1 -_2 +_3  ...
#
# ParticleNumber : Fermionic Operator
# register length=4, number terms=4
#   (1+0j) * ( +_0 -_0 )
# + (1+0j) * ( +_1 -_1 )
# + (1+0j) * ( +_2 -_2 )
# + (1+0j) * ( +_3 -_3 )
#
# AngularMomentum : Fermionic Operator
# register length=4, number terms=12
#   (1+0j) * ( +_0 -_1 -_2 +_3 )
# + (1+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.75+0j) * ( +_3 -_3 )
# + (0.75+0j) * ( +_2 -_2 )
# + (0.5+0j) * ( +_2 -_2 +_3 -_3 )
# + (0.75+0j) * ( +_1 -_1 )
# + (-1.5+0j) * ( +_1 -_1 ...
#
# Magnetization : Fermionic Operator
# register length=4, number terms=4
#   (0.5+0j) * ( +_0 -_0 )
# + (0.5+0j) * ( +_1 -_1 )
# + (-0.5+0j) * ( +_2 -_2 )
# + (-0.5+0j) * ( +_3 -_3 )
#
# -0.6015545188325717 * IIII
# - 0.4371518942035502 * ZIII
# + 0.23123526976934264 * IZII
# + 0.13921341316934566 * ZZII
# - 0.4371518942035502 * IIZI
# + 0.19043230782989573 * ZIZI
# + 0.18052927848009337 * IZZI
# + 0.23123526976934272 * IIIZ
# + 0.18052927848009337 * ZIIZ
# + 0.1834700765722127 * IZIZ
# + 0.13921341316934566 * IIZZ
# + 0.04131586531074771 * XXXX
# + 0.04131586531074771 * YYXX
# + 0.04131586531074771 * XXYY
# + 0.04131586531074771 * YYYY
# (-0.8799813451712628-2.7755575615628914e-17j) * II
# + (-0.6683871639728928-1.3877787807814457e-17j) * ZI
# + 0.6683871639728928 * IZ
# + (-0.012843827441921682-1.3877787807814457e-17j) * ZZ
# + 0.16526346124299082 * XX
# ElectronicEnergy : Fermionic Operator
# register length=4, number terms=14
#   (0.16845156058447724+0j) * ( +_0 -_1 +_2 -_3 )
# + (-0.16845156058447713+0j) * ( +_0 -_1 -_2 +_3 )
# + (-0.16845156058447713+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.1684515605844772+0j) * ( -_0 +_1 -_2 +_3 ) ...
#
# ParticleNumber : Fermionic Operator
# register length=4, number terms=4
#   (1+0j) * ( +_0 -_0 )
# + (1+0j) * ( +_1 -_1 )
# + (1+0j) * ( +_2 -_2 )
# + (1+0j) * ( +_3 -_3 )
#
# AngularMomentum : Fermionic Operator
# register length=4, number terms=12
#   (1+0j) * ( +_0 -_1 -_2 +_3 )
# + (1+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.75+0j) * ( +_3 -_3 )
# + (0.75+0j) * ( +_2 -_2 )
# + (0.5+0j) * ( +_2 -_2 +_3 -_3 )
# + (0.75+0j) * ( +_1 -_1 )
# + (-1.5+0j) * ( +_1 -_1 ...
#
# Magnetization : Fermionic Operator
# register length=4, number terms=4
#   (0.5+0j) * ( +_0 -_0 )
# + (0.5+0j) * ( +_1 -_1 )
# + (-0.5+0j) * ( +_2 -_2 )
# + (-0.5+0j) * ( +_3 -_3 )
#
# -0.6708186908275624 * IIII
# - 0.3762218809331721 * ZIII
# + 0.2157817187026428 * IZII
# + 0.1351155565316561 * ZZII
# - 0.37622188093317216 * IIZI
# + 0.18667914372638572 * ZIZI
# + 0.17722844667777538 * IZZI
# + 0.215781718702643 * IIIZ
# + 0.17722844667777538 * ZIIZ
# + 0.18033186514337157 * IZIZ
# + 0.1351155565316561 * IIZZ
# + 0.0421128901461193 * XXXX
# + 0.0421128901461193 * YYXX
# + 0.0421128901461193 * XXYY
# + 0.0421128901461193 * YYYY
# -0.9410498038908743 * II
# + (-0.5920035996358145-1.3877787807814457e-17j) * ZI
# + (0.5920035996358148+5.551115123125783e-17j) * IZ
# + (-0.012554115514206599-2.7755575615628914e-17j) * ZZ
# + (0.16845156058447716-3.469446951953614e-18j) * XX
# ElectronicEnergy : Fermionic Operator
# register length=4, number terms=14
#   (0.17191195012778582+0j) * ( +_0 -_1 +_2 -_3 )
# + (-0.1719119501277858+0j) * ( +_0 -_1 -_2 +_3 )
# + (-0.1719119501277858+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.17191195012778587+0j) * ( -_0 +_1 -_2 +_3 )
#  ...
#
# ParticleNumber : Fermionic Operator
# register length=4, number terms=4
#   (1+0j) * ( +_0 -_0 )
# + (1+0j) * ( +_1 -_1 )
# + (1+0j) * ( +_2 -_2 )
# + (1+0j) * ( +_3 -_3 )
#
# AngularMomentum : Fermionic Operator
# register length=4, number terms=12
#   (1+0j) * ( +_0 -_1 -_2 +_3 )
# + (1+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.75+0j) * ( +_3 -_3 )
# + (0.75+0j) * ( +_2 -_2 )
# + (0.5+0j) * ( +_2 -_2 +_3 -_3 )
# + (0.75+0j) * ( +_1 -_1 )
# + (-1.5+0j) * ( +_1 -_1 ...
#
# Magnetization : Fermionic Operator
# register length=4, number terms=4
#   (0.5+0j) * ( +_0 -_0 )
# + (0.5+0j) * ( +_1 -_1 )
# + (-0.5+0j) * ( +_2 -_2 )
# + (-0.5+0j) * ( +_3 -_3 )
#
# -0.7265807915705147 * IIII
# - 0.3229848183939955 * ZIII
# + 0.20151939176834327 * IZII
# + 0.13089357267118223 * ZZII
# - 0.3229848183939955 * IIZI
# + 0.18295325190700595 * ZIZI
# + 0.17387156020312872 * IZZI
# + 0.20151939176834333 * IIIZ
# + 0.17387156020312872 * ZIIZ
# + 0.1770281271661913 * IZIZ
# + 0.13089357267118223 * IIZZ
# + 0.042977987531946454 * XXXX
# + 0.042977987531946454 * YYXX
# + 0.042977987531946454 * XXYY
# + 0.042977987531946454 * YYYY
# -0.9883679369128786 * II
# + (-0.5245042101623387-1.3877787807814457e-17j) * ZI
# + 0.5245042101623387 * IZ
# + (-0.012238258666939797+1.3877787807814457e-17j) * ZZ
# + (0.1719119501277858+3.469446951953614e-18j) * XX
# ElectronicEnergy : Fermionic Operator
# register length=4, number terms=14
#   (0.17560306912121043+0j) * ( +_0 -_1 +_2 -_3 )
# + (-0.17560306912121035+0j) * ( +_0 -_1 -_2 +_3 )
# + (-0.17560306912121035+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.17560306912121026+0j) * ( -_0 +_1 -_2 +_3  ...
#
# ParticleNumber : Fermionic Operator
# register length=4, number terms=4
#   (1+0j) * ( +_0 -_0 )
# + (1+0j) * ( +_1 -_1 )
# + (1+0j) * ( +_2 -_2 )
# + (1+0j) * ( +_3 -_3 )
#
# AngularMomentum : Fermionic Operator
# register length=4, number terms=12
#   (1+0j) * ( +_0 -_1 -_2 +_3 )
# + (1+0j) * ( -_0 +_1 +_2 -_3 )
# + (0.75+0j) * ( +_3 -_3 )
# + (0.75+0j) * ( +_2 -_2 )
# + (0.5+0j) * ( +_2 -_2 +_3 -_3 )
# + (0.75+0j) * ( +_1 -_1 )
# + (-1.5+0j) * ( +_1 -_1 ...
#
# Magnetization : Fermionic Operator
# register length=4, number terms=4
#   (0.5+0j) * ( +_0 -_0 )
# + (0.5+0j) * ( +_1 -_1 )
# + (-0.5+0j) * ( +_2 -_2 )
# + (-0.5+0j) * ( +_3 -_3 )
#
# -0.7695983452007771 * IIII
# - 0.27721951158881136 * ZIII
# + 0.18836530871112583 * IZII
# + 0.12663786784875644 * ZZII
# - 0.2772195115888114 * IIZI
# + 0.17933182933916192 * ZIZI
# + 0.17053863512905904 * IZZI
# + 0.18836530871112578 * IIIZ
# + 0.17053863512905904 * ZIIZ
# + 0.17362191566135618 * IZIZ
# + 0.12663786784875644 * IIZZ
# + 0.04390076728030259 * XXXX
# + 0.04390076728030259 * YYXX
# + 0.04390076728030259 * XXYY
# + 0.04390076728030259 * YYYY
# -1.0228740808982897 * II
# + (-0.4655848202999371-1.3877787807814457e-17j) * ZI
# + (0.4655848202999371-2.7755575615628914e-17j) * IZ
# + (-0.0118764747424+1.3877787807814457e-17j) * ZZ
# + (0.1756030691212103+3.469446951953614e-18j) * XX
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-5a87e6eab9b5> in <module>
#      69
#      70     atomic_dist = [0.00, 0.002, ]
# ---> 71     result = vqe.compute_minimum_eigenvalue(operator=H2_op)
#      72
#      73 distance = []
#
# ~\anaconda3\lib\site-packages\qiskit\algorithms\minimum_eigen_solvers\vqe.py in compute_minimum_eigenvalue(self, operator, aux_operators)
#     542         # keep this until Optimizer.optimize is removed
#     543         try:
# --> 544             opt_result = self.optimizer.minimize(
#     545                 fun=energy_evaluation, x0=initial_point, jac=gradient, bounds=bounds
#     546             )
#
# ~\anaconda3\lib\site-packages\qiskit\algorithms\optimizers\spsa.py in minimize(self, fun, x0, jac, bounds)
#     549             iteration_start = time()
#     550             # compute update
# --> 551             fx_estimate, update = self._compute_update(fun, x, k, next(eps), lse_solver)
#     552
#     553             # trust region
#
# ~\anaconda3\lib\site-packages\qiskit\algorithms\optimizers\spsa.py in _compute_update(self, loss, x, k, eps, lse_solver)
#     484
#     485         # accumulate the number of samples
# --> 486         value, gradient, hessian = self._point_estimate(loss, x, eps, num_samples)
#     487
#     488         # precondition gradient with inverse Hessian, if specified
#
# ~\anaconda3\lib\site-packages\qiskit\algorithms\optimizers\spsa.py in _point_estimate(self, loss, x, eps, num_samples)
#     461             delta2 = deltas2[i] if self.second_order else None
#     462
# --> 463             value_sample, gradient_sample, hessian_sample = self._point_sample(
#     464                 loss, x, eps, delta1, delta2
#     465             )
#
# ~\anaconda3\lib\site-packages\qiskit\algorithms\optimizers\spsa.py in _point_sample(self, loss, x, eps, delta1, delta2)
#     422
#     423         # batch evaluate the points (if possible)
# --> 424         values = _batch_evaluate(loss, points, self._max_evals_grouped)
#     425
#     426         plus = values[0]
#
# ~\anaconda3\lib\site-packages\qiskit\algorithms\optimizers\spsa.py in _batch_evaluate(function, points, max_evals_grouped)
#     689     if max_evals_grouped == 1:
#     690         # support functions with multiple arguments where the points are given in a tuple
# --> 691         return [
#     692             function(*point) if isinstance(point, tuple) else function(point) for point in points
#     693         ]
#
# ~\anaconda3\lib\site-packages\qiskit\algorithms\optimizers\spsa.py in <listcomp>(.0)
#     690         # support functions with multiple arguments where the points are given in a tuple
#     691         return [
# --> 692             function(*point) if isinstance(point, tuple) else function(point) for point in points
#     693         ]
#     694
#
# ~\anaconda3\lib\site-packages\qiskit\algorithms\minimum_eigen_solvers\vqe.py in energy_evaluation(parameters)
#     626
#     627             start_time = time()
# --> 628             sampled_expect_op = self._circuit_sampler.convert(expect_op, params=param_bindings)
#     629             means = np.real(sampled_expect_op.eval())
#     630
#
# ~\anaconda3\lib\site-packages\qiskit\opflow\converters\circuit_sampler.py in convert(self, operator, params)
#     216         circs = list(self._circuit_ops_cache.values()) if not self._transpiled_circ_cache else None
#     217         p_b = cast(List[Dict[Parameter, float]], param_bindings)
# --> 218         sampled_statefn_dicts = self.sample_circuits(circuit_sfns=circs, param_bindings=p_b)
#     219
#     220         def replace_circuits_with_dicts(operator, param_index=0):
#
# ~\anaconda3\lib\site-packages\qiskit\opflow\converters\circuit_sampler.py in sample_circuits(self, circuit_sfns, param_bindings)
#     335             )
#     336
# --> 337         results = self.quantum_instance.execute(
#     338             ready_circs, had_transpiled=self._transpile_before_bind
#     339         )
#
# ~\anaconda3\lib\site-packages\qiskit\utils\quantum_instance.py in execute(self, circuits, had_transpiled)
#     772         else:
#     773             result = (
# --> 774                 run_circuits(
#     775                     circuits,
#     776                     self._backend,
#
# ~\anaconda3\lib\site-packages\qiskit\utils\run_circuits.py in run_circuits(circuits, backend, qjob_config, backend_options, noise_config, run_config, job_callback, max_job_retries)
#     605         results = []
#     606         for job in jobs:
# --> 607             results.append(job.result())
#     608
#     609     result = _combine_result_objects(results) if results else None
#
# ~\anaconda3\lib\site-packages\qiskit\providers\aer\jobs\utils.py in _wrapper(self, *args, **kwargs)
#      39         if self._future is None:
#      40             raise JobError("Job not submitted yet!. You have to .submit() first!")
# ---> 41         return func(self, *args, **kwargs)
#      42     return _wrapper
#      43
#
# ~\anaconda3\lib\site-packages\qiskit\providers\aer\jobs\aerjob.py in result(self, timeout)
#      76             concurrent.futures.CancelledError: if job cancelled before completed.
#      77         """
# ---> 78         return self._future.result(timeout=timeout)
#      79
#      80     @requires_submit
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # &#128211; Pick your favorite simple Hamiltonian of Pauli Operators (Heisenberg, Ising, Tight Binding, etc.).  Use VQE to find the ground state energy
#
# ### Use the opflow module of qiskit to create the operator.  You can find the tutorial [here](https://qiskit.org/documentation/tutorials/operators/01_operator_flow.html).

# %%
#Compare the VQE result with the exact eigenvalue using the NumpyMinimumEigenSolver().  I'd recommend keeping
#  the total size of the operators to be < 5 qubits.  You should just need the Pauli ops imported below.
#
from qiskit.opflow import I, X, Y, Z
#
# Your code goes here
#
#

J = 1.0
g = 1.
ZZs = (Z^Z^I) + (I^Z^Z)
Xs = (X^I^I) + (I^X^I) + (I^I^X)
H = -J*(ZZs + (g*Xs))
    
npme = NumPyMinimumEigensolver()
result_HIsing = npme.compute_minimum_eigenvalue(operator=H)
ref_value_HIsing = result_npme.eigenvalue.real
print(f'HIsing on Aer qasm simulator (no noise): {result.eigenvalue.real:.7f}')
print(f'Delta from reference energy value is {(result.eigenvalue.real - ref_value_HIsing):.7f}')

print(ref_value_HIsing)

# VQE minimum EV

# OPIMIZER = cobyla


seed = 170
iterations = 125
algorithm_globals.random_seed = seed
backend = Aer.get_backend('statevector_simulator')
qi = QuantumInstance(backend=backend, seed_simulator=seed, seed_transpiler=seed)



counts_cobyla = []
values_cobyla = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts_cobyla.append(eval_count)
    values_cobyla.append(mean)


    # we will probabaly play with the ansatz
#ansatz = TwoLocal(rotation_blocks='ry', entanglement_blocks='cz')
ansatz = EfficientSU2(num_qubits=4, entanglement='linear')
cobyla= COBYLA(maxiter=iterations)
vqe = VQE(ansatz, optimizer=cobyla, callback=store_intermediate_result, quantum_instance=qi)



result = vqe.compute_minimum_eigenvalue(operator=H)
print(result)
Minimum_Value = min(values_cobyla)
print("Minimum_Value = ", Minimum_Value)

Energy_difference = abs(Minimum_Value - ref_value_HIsing)
print("Energy difference = ",Energy_difference)

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(counts_cobyla, values_cobyla)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# HIsing on Aer qasm simulator (no noise): -2.0375957
# Delta from reference energy value is -0.1803206
# -1.8572750815566381
# {   'aux_operator_eigenvalues': None,
#     'cost_function_evals': 125,
#     'eigenstate': array([0.44860163+0.17052061j, 0.19256163+0.10408119j,
#        0.13874491+0.11265384j, 0.19146096+0.12888125j,
#        0.21616862+0.22737485j, 0.16992667+0.1464866j ,
#        0.22223137+0.19732312j, 0.46176571+0.43156153j]),
#     'eigenvalue': (-3.3953592705638194+0j),
#     'optimal_parameters': {   ParameterVectorElement(θ[8]): 1.1172763169425821,
#                               ParameterVectorElement(θ[9]): -1.4589908389512714,
#                               ParameterVectorElement(θ[10]): 3.688041996174991,
#                               ParameterVectorElement(θ[11]): 1.2897048113058787,
#                               ParameterVectorElement(θ[15]): -3.378861303134353,
#                               ParameterVectorElement(θ[17]): 0.45746070662410787,
#                               ParameterVectorElement(θ[20]): -3.544376221850372,
#                               ParameterVectorElement(θ[16]): -1.573608823455797,
#                               ParameterVectorElement(θ[19]): 1.8218714707341859,
#                               ParameterVectorElement(θ[14]): 4.38069529596277,
#                               ParameterVectorElement(θ[22]): -1.1664864726612674,
#                               ParameterVectorElement(θ[21]): 0.04974584054213784,
#                               ParameterVectorElement(θ[18]): 1.607909733206647,
#                               ParameterVectorElement(θ[13]): -2.2667511656966153,
#                               ParameterVectorElement(θ[23]): -3.4504358957697026,
#                               ParameterVectorElement(θ[12]): 2.7993880497518586,
#                               ParameterVectorElement(θ[7]): 0.08633224561983988,
#                               ParameterVectorElement(θ[4]): -2.209443120430816,
#                               ParameterVectorElement(θ[0]): 0.2217339828893072,
#                               ParameterVectorElement(θ[2]): -0.4688177044615506,
#                               ParameterVectorElement(θ[5]): 3.7772218119977734,
#                               ParameterVectorElement(θ[6]): -2.5933645508822614,
#                               ParameterVectorElement(θ[1]): 4.25474204496617,
#                               ParameterVectorElement(θ[3]): -2.3004188737984075},
#     'optimal_point': array([ 0.22173398,  3.688042  ,  1.28970481,  2.79938805, -2.26675117,
#         4.3806953 , -3.3788613 , -1.57360882,  0.45746071,  1.60790973,
#         1.82187147,  4.25474204, -3.54437622,  0.04974584, -1.16648647,
#        -3.4504359 , -0.4688177 , -2.30041887, -2.20944312,  3.77722181,
#        -2.59336455,  0.08633225,  1.11727632, -1.45899084]),
#     'optimal_value': -3.3953592705638194,
#     'optimizer_evals': None,
#     'optimizer_time': 1.7951254844665527}
# Minimum_Value =  -3.3953592705638194
# Energy difference =  1.5380841890071812
# Text(0.5, 1.0, 'Convergence with no noise')

# %%
#Compare the VQE result with the exact eigenvalue using the NumpyMinimumEigenSolver().  I'd recommend keeping
#  the total size of the operators to be < 5 qubits.  You should just need the Pauli ops imported below.
#Using SLSQP
#
from qiskit.opflow import I, X, Y, Z
#
# Your code goes here
#
#

J = 1.0
g = 1.
ZZs = (Z^Z^I) + (I^Z^Z)
Xs = (X^I^I) + (I^X^I) + (I^I^X)
H = -J*(ZZs + (g*Xs))
    
npme = NumPyMinimumEigensolver()
result_HIsing = npme.compute_minimum_eigenvalue(operator=H)
ref_value_HIsing = result_npme.eigenvalue.real
print(f'HIsing on Aer qasm simulator (no noise): {result.eigenvalue.real:.7f}')
print(f'Delta from reference energy value is {(result.eigenvalue.real - ref_value_HIsing):.7f}')

print(ref_value_HIsing)

# VQE minimum EV

# OPIMIZER = SLSQP


seed = 170
iterations = 125
algorithm_globals.random_seed = seed
backend = Aer.get_backend('statevector_simulator')
qi = QuantumInstance(backend=backend, seed_simulator=seed, seed_transpiler=seed)



counts_SLSQP = []
values_SLSQP = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts_SLSQP.append(eval_count)
    values_SLSQP.append(mean)


    # we will probabaly play with the ansatz
#ansatz = TwoLocal(rotation_blocks='ry', entanglement_blocks='cz')
ansatz = EfficientSU2(num_qubits=4, entanglement='linear')
slsqp=SLSQP(maxiter=iterations)
vqe = VQE(ansatz, optimizer=slsqp, callback=store_intermediate_result, quantum_instance=qi)



result = vqe.compute_minimum_eigenvalue(operator=H)
print(result)
Minimum_Value = min(values_SLSQP)
print("Minimum_Value = ", Minimum_Value)

Energy_difference = abs(Minimum_Value - ref_value_HIsing)
print("Energy difference = ",Energy_difference)

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(counts_SLSQP, values_SLSQP)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# HIsing on Aer qasm simulator (no noise): -3.3953593
# Delta from reference energy value is -1.5380842
# -1.8572750815566381
# {   'aux_operator_eigenvalues': None,
#     'cost_function_evals': 1009,
#     'eigenstate': array([-0.44811749-0.28759788j, -0.24864969-0.15964943j,
#        -0.17211098-0.11045079j, -0.248589  -0.15970714j,
#        -0.24877011-0.15965776j, -0.17210044-0.11057304j,
#        -0.24869687-0.15959868j, -0.44810973-0.28756357j]),
#     'eigenvalue': (-3.493959030494765+0j),
#     'optimal_parameters': {   ParameterVectorElement(θ[2]): -1.228080470969651,
#                               ParameterVectorElement(θ[3]): -1.612861275260494,
#                               ParameterVectorElement(θ[10]): 2.3746114973540617,
#                               ParameterVectorElement(θ[0]): -0.45002760360290067,
#                               ParameterVectorElement(θ[1]): 2.5298696467659556,
#                               ParameterVectorElement(θ[9]): -1.3861337740719908,
#                               ParameterVectorElement(θ[4]): -2.300593038855468,
#                               ParameterVectorElement(θ[5]): 3.09456834936953,
#                               ParameterVectorElement(θ[8]): 2.963190181307589,
#                               ParameterVectorElement(θ[7]): 1.7676702983306884,
#                               ParameterVectorElement(θ[6]): -2.8178274085270014,
#                               ParameterVectorElement(θ[19]): 2.7349823031379352,
#                               ParameterVectorElement(θ[20]): -2.7821955697615888,
#                               ParameterVectorElement(θ[22]): -0.023671111605448172,
#                               ParameterVectorElement(θ[23]): -3.141592653589793,
#                               ParameterVectorElement(θ[21]): -0.33518236028121734,
#                               ParameterVectorElement(θ[18]): 1.7763243082149305,
#                               ParameterVectorElement(θ[17]): 0.15451954406124352,
#                               ParameterVectorElement(θ[14]): 2.50999571300678,
#                               ParameterVectorElement(θ[15]): -2.983801840978897,
#                               ParameterVectorElement(θ[13]): -3.0591309331676473,
#                               ParameterVectorElement(θ[16]): -2.9706473613332993,
#                               ParameterVectorElement(θ[12]): 2.7804887871227733,
#                               ParameterVectorElement(θ[11]): -0.05249783770652501},
#     'optimal_point': array([-0.4500276 ,  2.3746115 , -0.05249784,  2.78048879, -3.05913093,
#         2.50999571, -2.98380184, -2.97064736,  0.15451954,  1.77632431,
#         2.7349823 ,  2.52986965, -2.78219557, -0.33518236, -0.02367111,
#        -3.14159265, -1.22808047, -1.61286128, -2.30059304,  3.09456835,
#        -2.81782741,  1.7676703 ,  2.96319018, -1.38613377]),
#     'optimal_value': -3.493959030494765,
#     'optimizer_evals': None,
#     'optimizer_time': 11.948022365570068}
# Minimum_Value =  -3.493959030494765
# Energy difference =  1.636683948938127
# Text(0.5, 1.0, 'Convergence with no noise')

# %%
#Compare the VQE result with the exact eigenvalue using the NumpyMinimumEigenSolver().  I'd recommend keeping
#  the total size of the operators to be < 5 qubits.  You should just need the Pauli ops imported below.
#
from qiskit.opflow import I, X, Y, Z
#
# Your code goes here
#
#

J = 1.0
g = 1.
ZZs = (Z^Z^I) + (I^Z^Z)
Xs = (X^I^I) + (I^X^I) + (I^I^X)
H = -J*(ZZs + (g*Xs))
    
npme = NumPyMinimumEigensolver()
result_HIsing = npme.compute_minimum_eigenvalue(operator=H)
ref_value_HIsing = result_npme.eigenvalue.real
print(f'HIsing on Aer qasm simulator (no noise): {result.eigenvalue.real:.7f}')
print(f'Delta from reference energy value is {(result.eigenvalue.real - ref_value_HIsing):.7f}')

print(ref_value_HIsing)

# VQE minimum EV

# OPIMIZER = bfgs


seed = 170
iterations = 125
algorithm_globals.random_seed = seed
backend = Aer.get_backend('statevector_simulator')
qi = QuantumInstance(backend=backend, seed_simulator=seed, seed_transpiler=seed)



counts_SLSQP = []
values_SLSQP = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts_SLSQP.append(eval_count)
    values_SLSQP.append(mean)


    # we will probabaly play with the ansatz
#ansatz = TwoLocal(rotation_blocks='ry', entanglement_blocks='cz')
ansatz = EfficientSU2(num_qubits=4, entanglement='linear')
bfgs = L_BFGS_B(maxiter=iterations)
vqe = VQE(ansatz, optimizer=bfgs, callback=store_intermediate_result, quantum_instance=qi)



result = vqe.compute_minimum_eigenvalue(operator=H)
print(result)
Minimum_Value = min(values_SLSQP)
print("Minimum_Value = ", Minimum_Value)

Energy_difference = abs(Minimum_Value - ref_value_HIsing)
print("Energy difference = ",Energy_difference)

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12, 4))
ax = fig.add_axes([1,1,1,1])
ax.plot(counts_SLSQP, values_SLSQP)
ax.set_xlabel('Eval count', size=18)
ax.set_ylabel('Energy', size=18)
ax.set_title('Convergence with no noise', size=20)
# Out:
# HIsing on Aer qasm simulator (no noise): -3.4939590
# Delta from reference energy value is -1.6366839
# -1.8572750815566381
# {   'aux_operator_eigenvalues': None,
#     'cost_function_evals': 1025,
#     'eigenstate': array([-0.23897743-0.33373728j, -0.29142581-0.24044996j,
#        -0.07443625-0.18158786j, -0.1389978 -0.21277598j,
#        -0.1634763 -0.27677802j, -0.15018454-0.18123002j,
#        -0.15713445-0.2486858j , -0.34220325-0.47253138j]),
#     'eigenvalue': (-3.3703848376694965+0j),
#     'optimal_parameters': {   ParameterVectorElement(θ[11]): 0.2522917246335257,
#                               ParameterVectorElement(θ[18]): 1.862630369932216,
#                               ParameterVectorElement(θ[17]): 0.02960972383814834,
#                               ParameterVectorElement(θ[10]): 2.816874461662332,
#                               ParameterVectorElement(θ[1]): 3.141592653589793,
#                               ParameterVectorElement(θ[0]): -0.3755092144995051,
#                               ParameterVectorElement(θ[4]): -1.7636392970263948,
#                               ParameterVectorElement(θ[8]): 2.4234338447391823,
#                               ParameterVectorElement(θ[7]): 2.1278199565050824,
#                               ParameterVectorElement(θ[6]): -3.1304925677684134,
#                               ParameterVectorElement(θ[2]): -0.3789515545937029,
#                               ParameterVectorElement(θ[5]): 2.544263338988462,
#                               ParameterVectorElement(θ[3]): -1.8522100458221717,
#                               ParameterVectorElement(θ[9]): -1.3968545870042375,
#                               ParameterVectorElement(θ[13]): -3.141592653589793,
#                               ParameterVectorElement(θ[12]): 3.0420304047492395,
#                               ParameterVectorElement(θ[15]): -2.61094014377516,
#                               ParameterVectorElement(θ[14]): 2.5472316766719865,
#                               ParameterVectorElement(θ[16]): -3.116144977845945,
#                               ParameterVectorElement(θ[20]): -2.4560077869632093,
#                               ParameterVectorElement(θ[23]): -3.089935873273705,
#                               ParameterVectorElement(θ[21]): -0.13936139062502698,
#                               ParameterVectorElement(θ[22]): -0.10190347543674351,
#                               ParameterVectorElement(θ[19]): 2.563484840829949},
#     'optimal_point': array([-0.37550921,  2.81687446,  0.25229172,  3.0420304 , -3.14159265,
#         2.54723168, -2.61094014, -3.11614498,  0.02960972,  1.86263037,
#         2.56348484,  3.14159265, -2.45600779, -0.13936139, -0.10190348,
#        -3.08993587, -0.37895155, -1.85221005, -1.7636393 ,  2.54426334,
#        -3.13049257,  2.12781996,  2.42343384, -1.39685459]),
#     'optimal_value': -3.3703848376694965,
#     'optimizer_evals': None,
#     'optimizer_time': 13.68165636062622}
# Minimum_Value =  -3.37038484033316
# Energy difference =  1.5131097587765219
# Text(0.5, 1.0, 'Convergence with no noise')
